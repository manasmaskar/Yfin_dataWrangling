# %% [markdown]
# <H1>Technological Sector

# %% [markdown]
# <h3> Fethc Apple Data for test </h1>

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'AAPL'

# Retrieve historical data using yfinance
apple_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = apple_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = apple_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
apple_data['MACD'] = macd_line
apple_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(apple_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 2005-01-03  1.156786  1.162679  1.117857  1.130179   0.956809   691992000
# 2005-01-04  1.139107  1.169107  1.124464  1.141786   0.966635  1096810400
# 2005-01-05  1.151071  1.165179  1.143750  1.151786   0.975101   680433600
# 2005-01-06  1.154821  1.159107  1.130893  1.152679   0.975858   705555200
# 2005-01-07  1.160714  1.243393  1.156250  1.236607   1.046911  2227450400
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04  0.000220     0.000122
# 2005-01-05  0.000543     0.000295
# 2005-01-06  0.000704     0.000434
# 2005-01-07  0.003604     0.001377

# %%
apple_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2005-01-03    1.156786    1.162679    1.117857    1.130179    0.956809
# 2005-01-04    1.139107    1.169107    1.124464    1.141786    0.966635
# 2005-01-05    1.151071    1.165179    1.143750    1.151786    0.975101
# 2005-01-06    1.154821    1.159107    1.130893    1.152679    0.975858
# 2005-01-07    1.160714    1.243393    1.156250    1.236607    1.046911
# ...                ...         ...         ...         ...         ...
# 2024-04-04  170.289993  171.919998  168.820007  168.820007  168.820007
# 2024-04-05  169.589996  170.389999  168.949997  169.580002  169.580002
# 2024-04-08  169.029999  169.199997  168.240005  168.449997  168.449997
# 2024-04-09  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-04-10  168.800003  169.089996  167.110001  167.779999  167.779999
#
#                 Volume      MACD  Signal Line
# Date
# 2005-01-03   691992000  0.000000     0.000000
# ...

# %%
apple_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4850 entries, 2005-01-03 to 2024-04-10
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Open         4850 non-null   float64
#  1   High         4850 non-null   float64
#  2   Low          4850 non-null   float64
#  3   Close        4850 non-null   float64
#  4   Adj Close    4850 non-null   float64
#  5   Volume       4850 non-null   int64
#  6   MACD         4850 non-null   float64
#  7   Signal Line  4850 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 341.0 KB

# %% [markdown]
# <h4
# >Fetch Microsoft Corporation MSFT </h1>

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'MSFT'

# Retrieve historical data using yfinance
microsoft_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = microsoft_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = microsoft_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
microsoft_data['MACD'] = macd_line
microsoft_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(microsoft_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2005-01-03  26.799999  26.950001  26.650000  26.740000  18.660549   65002900
# 2005-01-04  26.870001  27.100000  26.660000  26.840000  18.730331  109442100
# 2005-01-05  26.840000  27.100000  26.760000  26.780001  18.688456   72463500
# 2005-01-06  26.850000  27.059999  26.639999  26.750000  18.667526   76890500
# 2005-01-07  26.820000  26.889999  26.620001  26.670000  18.611700   68723300
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04  0.001566     0.000870
# 2005-01-05  0.000696     0.000799
# 2005-01-06 -0.000472     0.000368
# 2005-01-07 -0.003318    -0.000728

# %% [markdown]
# <h3>Fetching Google's Stock profile (Alphabet Inc.) GOOGL

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'GOOGL'

# Retrieve historical data using yfinance
google_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = google_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = google_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
google_data['MACD'] = macd_line
google_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(google_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2005-01-03  4.939940  5.096096  4.891391  5.072823   5.072823  633134232
# 2005-01-04  5.040040  5.078328  4.841842  4.867367   4.867367  549685764
# 2005-01-05  4.841091  4.927427  4.810561  4.842593   4.842593  329134536
# 2005-01-06  4.881882  4.902402  4.697698  4.718468   4.718468  415068516
# 2005-01-07  4.770771  4.861111  4.724224  4.851101   4.851101  386129484
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.004610    -0.002561
# 2005-01-05 -0.006642    -0.004233
# 2005-01-06 -0.011885    -0.006825
# 2005-01-07 -0.009206    -0.007533

# %% [markdown]
# <h1> Financial Sector </h1>

# %% [markdown]
# <h3>JP Morgan and Company JPMC --> JPM

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'JPM'

# Retrieve historical data using yfinance
jpmc_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = jpmc_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = jpmc_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
jpmc_data['MACD'] = macd_line
jpmc_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(jpmc_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  39.480000  39.689999  39.009998  39.150002  23.109800  14957900
# 2005-01-04  38.980000  39.060001  38.320000  38.410000  22.871626  11360900
# 2005-01-05  38.599998  38.919998  38.389999  38.490002  22.919254   9770200
# 2005-01-06  38.770000  38.980000  38.639999  38.709999  23.050247   9115900
# 2005-01-07  38.689999  38.869999  38.389999  38.400002  22.865667   9971200
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.005344    -0.002969
# 2005-01-05 -0.005332    -0.003937
# 2005-01-06 -0.000466    -0.002762
# 2005-01-07 -0.005158    -0.003474

# %% [markdown]
# <h3> Bank of America --> BAC

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'BAC'

# Retrieve historical data using yfinance
bac_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = bac_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = bac_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
bac_data['MACD'] = macd_line
bac_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(bac_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  46.660000  46.950001  46.180000  46.459999  30.233078  10238100
# 2005-01-04  46.410000  46.730000  45.740002  45.820000  29.816610  10264100
# 2005-01-05  45.639999  45.939999  45.250000  45.290001  29.471714  14796100
# 2005-01-06  45.419998  45.630001  44.990002  45.220001  29.426161  14602200
# 2005-01-07  45.299999  45.360001  44.720001  44.730000  29.107313  10547200
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.009344    -0.005191
# 2005-01-05 -0.022601    -0.012326
# 2005-01-06 -0.029722    -0.018219
# 2005-01-07 -0.045653    -0.026380

# %% [markdown]
# <h3> Wells and Fargo Company --> WFC

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'WFC'

# Retrieve historical data using yfinance
wfc_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = wfc_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = wfc_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
wfc_data['MACD'] = macd_line
wfc_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(wfc_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2005-01-03  31.115000  31.165001  30.875000  30.955000  18.059322  8168200
# 2005-01-04  30.975000  31.250000  30.885000  30.980000  18.073902  9241400
# 2005-01-05  31.040001  31.375000  30.975000  31.014999  18.094316  7694600
# 2005-01-06  31.049999  31.150000  30.900000  31.125000  18.158495  8887600
# 2005-01-07  31.170000  31.280001  31.030001  31.084999  18.135162  6573200
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04  0.000327     0.000182
# 2005-01-05  0.001050     0.000538
# 2005-01-06  0.003670     0.001599
# 2005-01-07  0.004088     0.002339

# %% [markdown]
# <h1> HealthCare

# %% [markdown]
# <h3> Johnson and Johnson J&J --> JNJ

# %%
import yfinance as yf
import pandas as pd

# Define the ticker symbol
ticker_symbol = 'JNJ'

# Retrieve historical data using yfinance
jnj_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = jnj_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = jnj_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
jnj_data['MACD'] = macd_line
jnj_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(jnj_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2005-01-03  63.349998  63.549999  62.689999  62.900002  36.439770  7859500
# 2005-01-04  63.099998  63.240002  62.619999  62.700001  36.323902  6989600
# 2005-01-05  62.869999  63.090000  62.590000  62.660000  36.300724  6888100
# 2005-01-06  62.750000  63.090000  62.689999  62.840000  36.405018  5277500
# 2005-01-07  62.980000  63.000000  62.570000  62.610001  36.271778  5037800
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.002600    -0.001444
# 2005-01-05 -0.004031    -0.002504
# 2005-01-06 -0.000818    -0.001933
# 2005-01-07 -0.004357    -0.002654

# %% [markdown]
# <h3> Pfizer Inc. PFE

# %%
# Define the ticker symbol
ticker_symbol = 'PFE'

# Retrieve historical data using yfinance
pfizer_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = pfizer_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = pfizer_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
pfizer_data['MACD'] = macd_line
pfizer_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(pfizer_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  25.910816  25.948767  25.094877  25.094877  11.658276  48649056
# 2005-01-04  25.056927  25.237192  24.696396  25.094877  11.658276  43660264
# 2005-01-05  25.123341  25.161289  24.810247  24.924099  11.578946  28956331
# 2005-01-06  25.047438  25.161289  24.933586  24.943073  11.587757  22101010
# 2005-01-07  25.180265  25.237192  24.924099  24.952562  11.592164  23528020
#
#                MACD  Signal Line
# Date
# 2005-01-03  0.00000     0.000000
# 2005-01-04  0.00000     0.000000
# 2005-01-05 -0.00246    -0.001008
# 2005-01-06 -0.00320    -0.001751
# 2005-01-07 -0.00336    -0.002230

# %% [markdown]
# <h3>Merk and Co.

# %%
# Define the ticker symbol
ticker_symbol = 'MRK'

# Retrieve historical data using yfinance
merk_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = merk_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = merk_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
merk_data['MACD'] = macd_line
merk_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(merk_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  30.524809  30.753817  29.561069  29.828243  14.845135  18835390
# 2005-01-04  30.028625  30.152672  29.589695  29.704199  14.783400  13575792
# 2005-01-05  29.704199  30.200382  29.627863  29.904579  14.883132  16589211
# 2005-01-06  30.057253  30.286261  29.904579  30.114504  14.987603   7538788
# 2005-01-07  30.076336  30.152672  29.694656  29.704199  14.783400  10808758
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.001385    -0.000769
# 2005-01-05  0.001328     0.000090
# 2005-01-06  0.006301     0.002194
# 2005-01-07  0.000745     0.001763

# %% [markdown]
# <h1> Energy Sector

# %% [markdown]
# <h3>Exxon Mobil Corporation XOM

# %%
# Define the ticker symbol
ticker_symbol = 'XOM'

# Retrieve historical data using yfinance
exxon_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = exxon_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = exxon_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
exxon_data['MACD'] = macd_line
exxon_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(exxon_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  51.020000  51.020000  49.869999  50.090000  26.423195  16009200
# 2005-01-04  50.340000  50.599998  49.680000  49.750000  26.243837  16718000
# 2005-01-05  49.830002  50.110001  49.450001  49.490002  26.106693  12189100
# 2005-01-06  49.299999  50.189999  49.250000  50.119999  26.439016  13098700
# 2005-01-07  50.119999  50.259998  49.520000  49.790001  26.264938  11315300
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.004024    -0.002236
# 2005-01-05 -0.009380    -0.005164
# 2005-01-06  0.000412    -0.003275
# 2005-01-07 -0.001203    -0.002659

# %% [markdown]
# <h3> Chevron Corporation --> CVX

# %%
# Define the ticker symbol
ticker_symbol = 'CVX'

# Retrieve historical data using yfinance
chevron_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = exxon_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = chevron_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
chevron_data['MACD'] = macd_line
chevron_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(chevron_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close   Volume  \
# Date
# 2005-01-03  52.459999  52.470001  50.830002  50.900002  24.714960  7346800
# 2005-01-04  50.980000  51.459999  50.400002  50.549999  24.545010  7157500
# 2005-01-05  50.669998  51.250000  50.490002  50.880001  24.705240  5524000
# 2005-01-06  50.799999  51.950001  50.599998  51.730000  25.117971  5849700
# 2005-01-07  51.730000  51.740002  50.799999  51.150002  24.836340  5095100
#
#                 MACD  Signal Line
# Date
# 2005-01-03  1.708235     1.708235
# 2005-01-04  1.699326     1.703286
# 2005-01-05  1.585501     1.655013
# 2005-01-06  1.518741     1.608851
# 2005-01-07  1.496317     1.575374

# %% [markdown]
# <h3>ConocoPhillips COP

# %%
# Define the ticker symbol
ticker_symbol = 'COP'

# Retrieve historical data using yfinance
conocoPhillips_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = conocoPhillips_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = conocoPhillips_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
conocoPhillips_data['MACD'] = macd_line
conocoPhillips_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(conocoPhillips_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  33.054047  33.054047  31.982990  32.059223  16.981251   8557862
# 2005-01-04  32.143078  32.310787  31.746674  31.849586  16.870207   6862503
# 2005-01-05  31.788601  32.299355  31.559906  32.085903  16.995380  10011064
# 2005-01-06  32.085903  32.749119  32.040165  32.550919  17.241690   8744399
# 2005-01-07  32.550919  32.550919  32.070660  32.345093  17.132671   6936751
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.002491    -0.001384
# 2005-01-05  0.000707    -0.000527
# 2005-01-06  0.011037     0.003390
# 2005-01-07  0.012080     0.005976

# %% [markdown]
# <h1>Communication Services

# %% [markdown]
# <h3>Facebook Inc

# %%
# Define the ticker symbol
ticker_symbol = 'VZ'

# Retrieve historical data using yfinance
verizon_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = verizon_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = verizon_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
verizon_data['MACD'] = macd_line
verizon_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(verizon_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  36.692368  36.926193  36.305660  36.413578  13.871128   9236061
# 2005-01-04  36.584450  36.656395  35.838013  36.044857  13.730668  11680234
# 2005-01-05  36.080830  36.431564  35.936935  35.990898  13.710124   8201616
# 2005-01-06  35.613182  35.882977  35.208485  35.568214  13.680712   7844458
# 2005-01-07  35.793045  35.829018  35.343384  35.442310  13.632287   8424450
#
#                 MACD  Signal Line
# Date
# 2005-01-03  0.000000     0.000000
# 2005-01-04 -0.003151    -0.001751
# 2005-01-05 -0.004653    -0.002940
# 2005-01-06 -0.006283    -0.004073
# 2005-01-07 -0.008964    -0.005528

# %% [markdown]
# <h3> Facebook --> META

# %%
# Define the ticker symbol
ticker_symbol = 'META'

# Retrieve historical data using yfinance
facebook_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = facebook_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = facebook_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
facebook_data['MACD'] = macd_line
facebook_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
print(facebook_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2012-05-18  42.049999  45.000000  38.000000  38.230000  38.189480  573576400
# 2012-05-21  36.529999  36.660000  33.000000  34.029999  33.993931  168192700
# 2012-05-22  32.610001  33.590000  30.940001  31.000000  30.967144  101786600
# 2012-05-23  31.370001  32.500000  31.360001  32.000000  31.966084   73600000
# 2012-05-24  32.950001  33.209999  31.770000  33.029999  32.994991   50237200
#
#                 MACD  Signal Line
# Date
# 2012-05-18  0.000000     0.000000
# 2012-05-21 -0.094131    -0.052295
# 2012-05-22 -0.213802    -0.118486
# 2012-05-23 -0.226925    -0.155220
# 2012-05-24 -0.188335    -0.165071

# %%
facebook_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2012-05-18   42.049999   45.000000   38.000000   38.230000   38.189480
# 2012-05-21   36.529999   36.660000   33.000000   34.029999   33.993931
# 2012-05-22   32.610001   33.590000   30.940001   31.000000   30.967144
# 2012-05-23   31.370001   32.500000   31.360001   32.000000   31.966084
# 2012-05-24   32.950001   33.209999   31.770000   33.029999   32.994991
# ...                ...         ...         ...         ...         ...
# 2024-04-04  516.419983  530.000000  510.579987  510.920013  510.920013
# 2024-04-05  516.859985  530.700012  514.409973  527.340027  527.340027
# 2024-04-08  529.280029  531.489990  518.890015  519.250000  519.250000
# 2024-04-09  522.229980  525.869995  506.739990  516.900024  516.900024
# 2024-04-10  509.290009  522.559998  505.799988  519.830017  519.830017
#
#                Volume       MACD  Signal Line
# Date
# 2012-05-18  573576400   0.000000     0.000000
# ...

# %% [markdown]
# <h3>AT&T data --> T

# %%
# Define the ticker symbol
ticker_symbol = 'T'

# Retrieve historical data using yfinance
atnt_data = yf.download(ticker_symbol, start="2005-01-01", end="2024-04-11")

# Calculate short-term EMA
short_term_period = 12
short_ema = atnt_data['Adj Close'].ewm(span=short_term_period, min_periods=1).mean()

# Calculate long-term EMA
long_term_period = 26
long_ema = atnt_data['Adj Close'].ewm(span=long_term_period, min_periods=1).mean()

# Calculate MACD line
macd_line = short_ema - long_ema

# Calculate signal line (9-period EMA of MACD line)
signal_period = 9
signal_line = macd_line.ewm(span=signal_period, min_periods=1).mean()

# Add MACD and signal line to the DataFrame
atnt_data['MACD'] = macd_line
atnt_data['Signal Line'] = signal_line

# Print the first few rows of the data with MACD and signal line
atnt_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2005-01-03  19.622356  19.622356  19.305136  19.327795   4.718965  13108262
# 2005-01-04  19.456194  19.471298  19.123867  19.123867   4.669175  15728061
# 2005-01-05  19.206949  19.478851  19.199396  19.214502   4.691306  14649398
# 2005-01-06  19.161631  19.161631  18.897282  18.995468   4.717122  11942480
# 2005-01-07  19.070997  19.169184  18.927492  18.942598   4.703994  13383124
# ...               ...        ...        ...        ...        ...       ...
# 2024-04-04  17.620001  17.879999  17.559999  17.570000  17.286842  31850300
# 2024-04-05  17.520000  17.540001  17.280001  17.420000  17.139259  37757200
# 2024-04-08  17.400000  17.459999  17.219999  17.250000  16.972000  27372200
# 2024-04-09  17.000000  17.080000  16.809999  16.900000  16.900000  32802500
# ...

# %%
apple_data['company_name'] = 'apple'

# %%
microsoft_data['company_name'] = 'microsoft'
google_data['company_name'] = 'google'
jpmc_data['company_name'] = 'jpmc'
bac_data['company_name'] = 'boa'
wfc_data['company_name'] = 'wfc'
jnj_data['company_name'] = 'jnj'
pfizer_data['company_name']= 'pfizer'
merk_data['company_name']='merck'
exxon_data['company_name']='exxon'
chevron_data['company_name']='chevron'
facebook_data['company_name']='facebook'
verizon_data['company_name']='verizon'
atnt_data['company_name']='atnt'

# %%
bac_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'MACD',
#        'Signal Line', 'company_name'],
#       dtype='object')

# %%
combined_df_list = [
    apple_data,
    microsoft_data,
    google_data,
    jpmc_data,
    bac_data,
    wfc_data,
    jnj_data,
    pfizer_data,
    merk_data,
    exxon_data,
    chevron_data,
    facebook_data,
    verizon_data,
    atnt_data
]

combined_df = pd.concat(combined_df_list)

# %%
combined_df.reset_index(inplace=True)

# %%
combined_df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2005-01-03   1.156786   1.162679   1.117857   1.130179   0.956809
# 1     2005-01-04   1.139107   1.169107   1.124464   1.141786   0.966635
# 2     2005-01-05   1.151071   1.165179   1.143750   1.151786   0.975101
# 3     2005-01-06   1.154821   1.159107   1.130893   1.152679   0.975858
# 4     2005-01-07   1.160714   1.243393   1.156250   1.236607   1.046911
# ...          ...        ...        ...        ...        ...        ...
# 66037 2024-04-04  17.620001  17.879999  17.559999  17.570000  17.286842
# 66038 2024-04-05  17.520000  17.540001  17.280001  17.420000  17.139259
# 66039 2024-04-08  17.400000  17.459999  17.219999  17.250000  16.972000
# 66040 2024-04-09  17.000000  17.080000  16.809999  16.900000  16.900000
# 66041 2024-04-10  16.770000  16.790001  16.510000  16.730000  16.730000
#
#            Volume      MACD  Signal Line company_name
# ...

# %%
last_column = combined_df.pop('company_name')
combined_df.insert(0, 'company_name', last_column)

# %%
combined_df
# Out:
#       company_name       Date       Open       High        Low      Close  \
# 0            apple 2005-01-03   1.156786   1.162679   1.117857   1.130179
# 1            apple 2005-01-04   1.139107   1.169107   1.124464   1.141786
# 2            apple 2005-01-05   1.151071   1.165179   1.143750   1.151786
# 3            apple 2005-01-06   1.154821   1.159107   1.130893   1.152679
# 4            apple 2005-01-07   1.160714   1.243393   1.156250   1.236607
# ...            ...        ...        ...        ...        ...        ...
# 66037         atnt 2024-04-04  17.620001  17.879999  17.559999  17.570000
# 66038         atnt 2024-04-05  17.520000  17.540001  17.280001  17.420000
# 66039         atnt 2024-04-08  17.400000  17.459999  17.219999  17.250000
# 66040         atnt 2024-04-09  17.000000  17.080000  16.809999  16.900000
# 66041         atnt 2024-04-10  16.770000  16.790001  16.510000  16.730000
#
#        Adj Close      Volume      MACD  Signal Line
# ...

# %%
combined_df.isnull().sum()
# Out:
# company_name    0
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# MACD            0
# Signal Line     0
# dtype: int64

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66042 entries, 0 to 66041
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  66042 non-null  object
#  1   Date          66042 non-null  datetime64[ns]
#  2   Open          66042 non-null  float64
#  3   High          66042 non-null  float64
#  4   Low           66042 non-null  float64
#  5   Close         66042 non-null  float64
#  6   Adj Close     66042 non-null  float64
#  7   Volume        66042 non-null  int64
#  8   MACD          66042 non-null  float64
#  9   Signal Line   66042 non-null  float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 5.0+ MB

# %%
file_path = 'companies_and_stock_info'
combined_df.to_csv(file_path,index=False)

# %%
company_data = {}
for company, group in combined_df.groupby('company_name'):
    company_data[company] = []
    for index, row in group.iterrows():
        company_data[company].append({
            'date': row['Date'],
            'open': row['Open'],
            'high': row['High'],
            'low': row['Low'],
            'close': row['Close'],
            'adj_close': row['Adj Close'],
            'volume': row['Volume'],
            'macd': row['MACD'],
            'signal_line': row['Signal Line']
        })



file_path = 'JSONcompanies_and_stock_info'
combined_df.to_json(file_path,orient='records')

# %%
import pandas as pd
import json

# Assuming 'df' is your DataFrame which is already loaded with data

# Convert the DataFrame to the desired JSON structure
result = {}
for name, group in combined_df.groupby('company_name'):
    # Convert date to string in ISO format (or any other format you prefer)
    group['Date'] = group['Date'].dt.strftime('%Y-%m-%d')
    # Organize the data by date within each company's data
    group_data = group.drop(columns='company_name').set_index('Date')
    result[name] = group_data.to_dict(orient='index')

# Convert to JSON string (optional, only if you need to serialize it to a JSON format string)
json_result = json.dumps(result, indent=4)

# To see the result in the console or to debug
print(json_result)

# If you need to write the JSON to a file
with open('json_CombinedStocks.json', 'w') as f:
    json.dump(result, f, indent=4)

# %%
combined_df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  66042.000000  66042.000000  66042.000000  66042.000000  66042.000000
# mean      63.722990     64.343411     63.096231     63.734708     52.813230
# std       56.549707     57.140181     55.973503     56.579686     56.727241
# min        1.139107      1.159107      1.117857      1.130179      0.956809
# 25%       27.740000     28.017078     27.410000     27.723999     18.464321
# 50%       46.312500     46.759998     45.893473     46.310001     34.712898
# 75%       82.638397     83.379997     81.930000     82.690002     61.737027
# max      529.280029    531.489990    518.890015    527.340027    527.340027
#
#              Volume          MACD   Signal Line
# count  6.604200e+04  66042.000000  66042.000000
# mean   6.353079e+07     -1.240202     -1.239155
# std    1.548333e+08      7.471101      7.448345
# min    1.587800e+06    -73.350666    -72.815908
# ...

# %%
import pandas as pd
import pymysql
from pymysql import connect, err

# Assuming 'df' is your DataFrame loaded with data

# MySQL connection parameters
host = 'localhost'
database = 'stockForecasting'
user = 'root'
password = 'Plum@08901'

try:
    # Connect to the MySQL database
    conn = connect(host=host, user=user, password=password, database=database)
    print('Successfully connected to MySQL database')

    # Create a cursor object
    cursor = conn.cursor()

    # Create table if it does not exist
    cursor.execute(
        '''
        CREATE TABLE IF NOT EXISTS stock_prices (
            company_name VARCHAR(255),
            Date DATE,
            Open FLOAT,
            High FLOAT,
            Low FLOAT,
            Close FLOAT,
            Adj_Close FLOAT,
            Volume BIGINT,
            MACD FLOAT,
            Signal_Line FLOAT
        );
        '''
    )

    # Insert DataFrame records one by one
    for i, row in combined_df.iterrows():
        sql = """
        INSERT INTO stock_prices (company_name, Date, Open, High, Low, Close, Adj_Close, Volume, MACD, Signal_Line)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
        """
        cursor.execute(sql, tuple(row))

    # Commit the changes
    conn.commit()
    print("Data inserted successfully")

except err.MySQLError as e:
    print('Error:', e)
finally:
    # Close the cursor and the connection
    if conn:
        cursor.close()
        conn.close()
        print('MySQL connection closed.')
# Out:
# Successfully connected to MySQL database
# Data inserted successfully
# MySQL connection closed.

# %%
combined_df.isnull().sum()
# Out:
# company_name    0
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Adj Close       0
# Volume          0
# MACD            0
# Signal Line     0
# dtype: int64

# %%
combined_df
# Out:
#       company_name       Date       Open       High        Low      Close  \
# 0            apple 2005-01-03   1.156786   1.162679   1.117857   1.130179
# 1            apple 2005-01-04   1.139107   1.169107   1.124464   1.141786
# 2            apple 2005-01-05   1.151071   1.165179   1.143750   1.151786
# 3            apple 2005-01-06   1.154821   1.159107   1.130893   1.152679
# 4            apple 2005-01-07   1.160714   1.243393   1.156250   1.236607
# ...            ...        ...        ...        ...        ...        ...
# 66037         atnt 2024-04-04  17.620001  17.879999  17.559999  17.570000
# 66038         atnt 2024-04-05  17.520000  17.540001  17.280001  17.420000
# 66039         atnt 2024-04-08  17.400000  17.459999  17.219999  17.250000
# 66040         atnt 2024-04-09  17.000000  17.080000  16.809999  16.900000
# 66041         atnt 2024-04-10  16.770000  16.790001  16.510000  16.730000
#
#        Adj Close      Volume      MACD  Signal Line
# ...

# %% [markdown]
# <H1>Performing TimeSeries Analysis

# %%
#first performing Basic Statistics on this dataFrame 
timeSeries_df = combined_df
timeSeries_df['Date'] = pd.to_datetime(timeSeries_df['Date'])


statistics = {
    'Mean': combined_df.mean(numeric_only=True),
    'Median': combined_df.median(numeric_only=True),
    'Standard Deviation': combined_df.std(numeric_only=True)
}


# Convert the statistics dictionary into a DataFrame
statistics_df = pd.DataFrame(statistics)

# Display statistics_df
statistics_df
# Out:
#                      Mean        Median  Standard Deviation
# Open         6.372299e+01  4.631250e+01        5.654971e+01
# High         6.434341e+01  4.676000e+01        5.714018e+01
# Low          6.309623e+01  4.589347e+01        5.597350e+01
# Close        6.373471e+01  4.631000e+01        5.657969e+01
# Adj Close    5.281323e+01  3.471290e+01        5.672724e+01
# Volume       6.353079e+07  2.262917e+07        1.548333e+08
# MACD        -1.240202e+00  6.566909e-02        7.471101e+00
# Signal Line -1.239155e+00  6.460009e-02        7.448345e+00

# %% [markdown]
# <h3>Visualization of the Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Convert 'Date' column to datetime


# Group the DataFrame by 'company_name'
groups = timeSeries_df.groupby('company_name')

# Plot each group separately with different colors
plt.figure(figsize=(10, 6))
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']  # You can add more colors if needed

for i, (company_name, group) in enumerate(groups):
    plt.plot(group['Date'], group['Close'], label=company_name, color=colors[i % len(colors)])

plt.title('Close Prices Over Time for Different Companies')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
# Convert 'Date' column to datetime


# Group the DataFrame by 'company_name'
groups = timeSeries_df.groupby('company_name')

# Plot each group separately with different colors
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']  # You can add more colors if needed

for i, (company_name, group) in enumerate(groups):
    plt.figure(figsize=(10, 6))
    plt.plot(group['Date'], group['Close'], label=company_name, color=colors[i % len(colors)])
    plt.title(f'Close Prices Over Time for {company_name}')
    plt.xlabel('Date')
    plt.ylabel('Close Price')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# <h5> Now Plotting the Stagnancy or Growth of a stock<br>
# <h6> This will be plotted on the basis of calculating the rolling average <br>
# <h6> Plotting the volume and rolling average<br>
# <h6> Then check for any different pattern <br>
# <h6> And finally, compare the Price movement

# %%
# Calculate rolling average of trading volume
window_size = 30  # You can adjust the window size as needed
rolling_avg_volume = timeSeries_df.groupby('company_name')['Volume'].rolling(window=window_size).mean()

# Plot volume and rolling average
plt.figure(figsize=(10, 6))
for company_name, group in timeSeries_df.groupby('company_name'):
    plt.figure(figsize=(10, 6))
    rolling_avg_volume = group['Volume'].rolling(window=window_size).mean()
    plt.plot(group['Date'], group['Volume'], label='Volume')
    plt.plot(group['Date'], rolling_avg_volume, label='Rolling Average Volume', linestyle='--')
    plt.title(f'Trading Volume and Rolling Average Volume Over Time for {company_name}')
    plt.xlabel('Date')
    plt.ylabel('Volume')
    plt.legend()
    plt.grid(True)
    plt.show()
